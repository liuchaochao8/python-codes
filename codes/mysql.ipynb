# %%
from pyecharts import options as opts
from pyecharts.charts import Scatter, Page
from pyecharts.globals import SymbolType
import pymysql

# %%
# 打开数据库连接
db = pymysql.connect(host='namenode',
                     user='root',
                     password='hadoop',
                     database='zhaopin')

# %%
cur = db.cursor()
cur.execute("select * from need_detail")
sh = cur.fetchall() 
v1 = []
v2 = []
for s in sh:            #根据顺序将相应属性数据传入变量
    v1.append(s[0])
    v2.append(s[1])

def scatter_splitline() -> Scatter:
    c = (
        Scatter()
        .add_xaxis(v1)
        .add_yaxis("数量", v2,label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="需求分析", subtitle="数量"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(type_="value",min_=20,max_=200,axistick_opts=opts.AxisTickOpts(is_show=True),splitline_opts=opts.SplitLineOpts(is_show=True)),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=True)
        )
    )
    return c

#第一次渲染时候调用load_javasrcript文件
scatter_splitline().load_javascript()
#展示数据可视化图表
scatter_splitline().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="6f81469be30e440db75152287456a926" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_6f81469be30e440db75152287456a926 = echarts.init(
#                     document.getElementById('6f81469be30e440db75152287456a926'), 'white', {renderer: 'canvas'});
#                 var option_6f81469be30e440db75152287456a926 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
cur = db.cursor()
cur.execute("select * from welfare_detail")
sh = cur.fetchall() 
v1 = []
v2 = []
for s in sh:            #根据顺序将相应属性数据传入变量
    v1.append(s[0])
    v2.append(s[1])

def scatter_splitline() -> Scatter:
    c = (
        Scatter()
        .add_xaxis(v1)
        .add_yaxis("数量", v2,label_opts=opts.LabelOpts(is_show=False))
        .set_global_opts(
            title_opts=opts.TitleOpts(title="福利分析", subtitle="数量"),
            xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
            yaxis_opts=opts.AxisOpts(type_="value",min_=10,max_=50,axistick_opts=opts.AxisTickOpts(is_show=True),splitline_opts=opts.SplitLineOpts(is_show=True)),
            toolbox_opts=opts.ToolboxOpts(),
            legend_opts=opts.LegendOpts(is_show=True)
        )
    )
    return c

#第一次渲染时候调用load_javasrcript文件
scatter_splitline().load_javascript()
#展示数据可视化图表
scatter_splitline().render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="8483a0f02492463182353dbb7ddc63aa" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_8483a0f02492463182353dbb7ddc63aa = echarts.init(
#                     document.getElementById('8483a0f02492463182353dbb7ddc63aa'), 'white', {renderer: 'canvas'});
#                 var option_8483a0f02492463182353dbb7ddc63aa = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Pie
cur = db.cursor()
cur.execute("select * from welfare_detail where welfare != 'nan' order by count desc")
sh = cur.fetchall() 
v1 = []
v2 = []
for s in sh:            #根据顺序将相应属性数据传入变量
    v1.append(s[0])
    v2.append(s[1])
del v1[1]
del v2[1]

pie = (
    Pie(init_opts=opts.InitOpts(width='1000px', height='600px'))
    .add(series_name='', data_pair=[(i, j)for i, j in zip(v1[0:8], v2[0:8])])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}"))
)
 
pie.render_notebook()
# pie.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="905db6d854cd4dd59e260dc34b939995" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_905db6d854cd4dd59e260dc34b939995 = echarts.init(
#                     document.getElementById('905db6d854cd4dd59e260dc34b939995'), 'white', {renderer: 'canvas'});
#                 var option_905db6d854cd4dd59e260dc34b939995 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Pie
cur = db.cursor()
cur.execute("select * from job_province_info")
sh = cur.fetchall() 
v1 = []
v2 = []
for s in sh:            #根据顺序将相应属性数据传入变量
    v1.append(s[0])
    v2.append(s[1])
del v1[1]
del v2[1]

pie = (
    Pie(init_opts=opts.InitOpts(width='1000px', height='600px'))
    .add(series_name='', data_pair=[(i, j)for i, j in zip(v1[0:10], v2[0:10])])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}")))
 
pie.render_notebook()
# pie.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="ae6bf369df234e5a95f64d3274bf3c55" style="width:1000px; height:600px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_ae6bf369df234e5a95f64d3274bf3c55 = echarts.init(
#                     document.getElementById('ae6bf369df234e5a95f64d3274bf3c55'), 'white', {renderer: 'canvas'});
#                 var option_ae6bf369df234e5a95f64d3274bf3c55 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
from pyecharts.charts import Pie
cur = db.cursor()
cur.execute("select * from com_type_count")
sh = cur.fetchall() 
v1 = []
v2 = []
for s in sh:            #根据顺序将相应属性数据传入变量
    v1.append(s[0])
    v2.append(s[1])
del v1[1]
del v2[1]

pie = (
    Pie(init_opts=opts.InitOpts(width='1000px', height='800px'))
    .add(series_name='', data_pair=[(i, j)for i, j in zip(v1[0:8], v2[0:8])])
    .set_series_opts(label_opts=opts.LabelOpts(formatter="{b}:{c}")))
 
pie.render_notebook()
# pie.render()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="302834b0509f4eac81482711164c575c" style="width:1000px; height:800px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_302834b0509f4eac81482711164c575c = echarts.init(
#                     document.getElementById('302834b0509f4eac81482711164c575c'), 'white', {renderer: 'canvas'});
#                 var option_302834b0509f4eac81482711164c575c = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...
