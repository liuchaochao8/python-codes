# %%
from sklearn.datasets import load_wine
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
wine = load_wine()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = wine.data
y = wine.target
X_scaled = scaler.fit_transform(X)
print (X_scaled.shape)
# Out:
# (178, 13)

# %%
from sklearn.decomposition import PCA
#设置主成分数量为2以便我们进行可视化
pca = PCA(n_components=2)
pca.fit(X_scaled)
X_pca = pca.transform(X_scaled)
print(X_pca.shape)
# Out:
# (178, 2)

# %%
import matplotlib.pyplot as plt
X0 = X_pca[wine.target==0]
X1 = X_pca[wine.target==1]
X2 = X_pca[wine.target==2]
plt.scatter(X0[:,0],X0[:,1],c='b',s=60,edgecolor='k')
plt.scatter(X1[:,0],X1[:,1],c='g',s=60,edgecolor='k')
plt.scatter(X2[:,0],X2[:,1],c='r',s=60,edgecolor='k')

plt.legend(wine.target_names, loc='best')
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.show()

# %%
plt.matshow(pca.components_, cmap='plasma')
plt.yticks([0,1],['component 1','component 2'])
plt.colorbar()
plt.xticks(range(len(wine.feature_names)),wine.feature_names,
          rotation=60,ha='left')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.colors import ListedColormap
from sklearn import tree, datasets
from sklearn.model_selection import train_test_split

path = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
#path = "iris.csv"
feature_name = ['sepal_length','sepal_width','petal-length', 'petal-width']
headernames = ['sepal_length','sepal_width','petal-length', 'petal-width', 'Class']
ir = pd.read_csv(path, names = headernames)
#dataset = pd.read_csv(path)
ir.head()
# Out:
#    sepal_length  sepal_width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#Class = dataset.Class.replace(['Iris-setosa','Iris-versicolor','Iris-virginica'],[0,1,2])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = ir.iloc[:, :-1].values
y = ir.Class
X_scaled = scaler.fit_transform(X)
print (X_scaled.shape)
# Out:
# (150, 4)

# %%
from sklearn.decomposition import PCA
#设置主成分数量为2以便我们进行可视化
pca = PCA(n_components=2)
pca.fit(X_scaled)
X_pca = pca.transform(X_scaled)
print(X_pca.shape)
# Out:
# (150, 2)

# %%
X0 = X_pca[ir.Class=='Iris-setosa']
X1 = X_pca[ir.Class=='Iris-versicolor']
X2 = X_pca[ir.Class=='Iris-virginica']
plt.scatter(X0[:,0],X0[:,1],c='b',s=60,edgecolor='k')
plt.scatter(X1[:,0],X1[:,1],c='g',s=60,edgecolor='k')
plt.scatter(X2[:,0],X2[:,1],c='r',s=60,edgecolor='k')

plt.legend(['Iris-setosa','Iris-versicolor','Iris-virginica'], loc='best')
plt.xlabel('component 1')
plt.ylabel('component 2')
plt.show()

# %%
plt.matshow(pca.components_, cmap='plasma')
plt.yticks([0,1],['component 1','component 2'])
plt.colorbar()
plt.xticks(range(len(feature_name)),feature_name,
          rotation=60,ha='left')
plt.show()
