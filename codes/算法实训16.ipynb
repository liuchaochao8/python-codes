# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import tree, datasets
from sklearn.model_selection import train_test_split
wine = datasets.load_wine()
X = wine.data[:,:2]
y = wine.target
X_train, X_test, y_train, y_test = train_test_split(X,y)
clf = tree.DecisionTreeClassifier(max_depth=1)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
# Out:
# array([[14.23,  1.71],
#        [13.2 ,  1.78],
#        [13.16,  2.36],
#        [14.37,  1.95],
#        [13.24,  2.59],
#        [14.2 ,  1.76],
#        [14.39,  1.87],
#        [14.06,  2.15],
#        [14.83,  1.64],
#        [13.86,  1.35],
#        [14.1 ,  2.16],
#        [14.12,  1.48],
#        [13.75,  1.73],
#        [14.75,  1.73],
#        [14.38,  1.87],
#        [13.63,  1.81],
#        [14.3 ,  1.92],
#        [13.83,  1.57],
#        [14.19,  1.59],
#        [13.64,  3.1 ],
#        [14.06,  1.63],
#        [12.93,  3.8 ],
#        [13.71,  1.86],
#        [12.85,  1.6 ],
#        [13.5 ,  1.81],
#        [13.05,  2.05],
#        [13.39,  1.77],
#        [13.3 ,  1.72],
#        [13.87,  1.9 ],
#        [14.02,  1.68],
#        [13.73,  1.5 ],
#        [13.58,  1.66],
#        [13.68,  1.83],
#        [13.76,  1.53],
#        [13.51,  1.8 ],
#        [13.48,  1.81],
#        [13.28,  1.64],
#        [13.05,  1.65],
#        [13.07,  1.5 ],
#        [14.22,  3.99],
#        [13.56,  1.71],
#        [13.41,  3.84],
#        [13.88,  1.89],
#        [13.24,  3.98],
#        [13.05,  1.77],
#        [14.21,  4.04],
#        [14.38,  3.59],
#        [13.9 ,  1.68],
#        [14.1 ,  2.02],
#        [13.94,  1.73],
#        [13.05,  1.73],
#        [13.83,  1.65],
#        [13.82,  1.75],
#        [13.77,  1.9 ],
#        [13.74,  1.67],
#        [13.56,  1.73],
#        [14.22,  1.7 ],
#        [13.29,  1.97],
#        [13.72,  1.43],
#        [12.37,  0.94],
#        [12.33,  1.1 ],
#        [12.64,  1.36],
#        [13.67,  1.25],
#        [12.37,  1.13],
#        [12.17,  1.45],
#        [12.37,  1.21],
#        [13.11,  1.01],
#        [12.37,  1.17],
#        [13.34,  0.94],
#        [12.21,  1.19],
#        [12.29,  1.61],
#        [13.86,  1.51],
#        [13.49,  1.66],
#        [12.99,  1.67],
#        [11.96,  1.09],
#        [11.66,  1.88],
#        [13.03,  0.9 ],
#        [11.84,  2.89],
#        [12.33,  0.99],
#        [12.7 ,  3.87],
#        [12.  ,  0.92],
#        [12.72,  1.81],
#        [12.08,  1.13],
#        [13.05,  3.86],
#        [11.84,  0.89],
#        [12.67,  0.98],
#        [12.16,  1.61],
#        [11.65,  1.67],
#        [11.64,  2.06],
#        [12.08,  1.33],
#        [12.08,  1.83],
#        [12.  ,  1.51],
#        [12.69,  1.53],
#        [12.29,  2.83],
#        [11.62,  1.99],
#        [12.47,  1.52],
#        [11.81,  2.12],
#        [12.29,  1.41],
#        [12.37,  1.07],
#        [12.29,  3.17],
#        [12.08,  2.08],
#        [12.6 ,  1.34],
#        [12.34,  2.45],
#        [11.82,  1.72],
#        [12.51,  1.73],
#        [12.42,  2.55],
#        [12.25,  1.73],
#        [12.72,  1.75],
#        [12.22,  1.29],
#        [11.61,  1.35],
#        [11.46,  3.74],
#        [12.52,  2.43],
#        [11.76,  2.68],
#        [11.41,  0.74],
#        [12.08,  1.39],
#        [11.03,  1.51],
#        [11.82,  1.47],
#        [12.42,  1.61],
#        [12.77,  3.43],
#        [12.  ,  3.43],
#        [11.45,  2.4 ],
#        [11.56,  2.05],
#        [12.42,  4.43],
#        [13.05,  5.8 ],
#        [11.87,  4.31],
#        [12.07,  2.16],
#        [12.43,  1.53],
#        [11.79,  2.13],
#        [12.37,  1.63],
#        [12.04,  4.3 ],
#        [12.86,  1.35],
#        [12.88,  2.99],
#        [12.81,  2.31],
#        [12.7 ,  3.55],
#        [12.51,  1.24],
#        [12.6 ,  2.46],
#        [12.25,  4.72],
#        [12.53,  5.51],
#        [13.49,  3.59],
#        [12.84,  2.96],
#        [12.93,  2.81],
#        [13.36,  2.56],
#        [13.52,  3.17],
#        [13.62,  4.95],
#        [12.25,  3.88],
#        [13.16,  3.57],
#        [13.88,  5.04],
#        [12.87,  4.61],
#        [13.32,  3.24],
#        [13.08,  3.9 ],
#        [13.5 ,  3.12],
#        [12.79,  2.67],
#        [13.11,  1.9 ],
#        [13.23,  3.3 ],
#        [12.58,  1.29],
#        [13.17,  5.19],
#        [13.84,  4.12],
#        [12.45,  3.03],
#        [14.34,  1.68],
#        [13.48,  1.67],
#        [12.36,  3.83],
#        [13.69,  3.26],
#        [12.85,  3.27],
#        [12.96,  3.45],
#        [13.78,  2.76],
#        [13.73,  4.36],
#        [13.45,  3.7 ],
#        [12.82,  3.37],
#        [13.58,  2.58],
#        [13.4 ,  4.6 ],
#        [12.2 ,  3.03],
#        [12.77,  2.39],
#        [14.16,  2.51],
#        [13.71,  5.65],
#        [13.4 ,  3.91],
#        [13.27,  4.28],
#        [13.17,  2.59],
#        [14.13,  4.1 ]])

# %%
clf.score(X_test, y_test)
# Out:
# 0.6888888888888889

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
import graphviz
from sklearn.tree import export_graphviz
export_graphviz(clf2, out_file="wine.dot", class_names=wine.target_names,
feature_names=wine.feature_names[:2], impurity=False, filled=True)
with open("wine.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import graphviz
#       2 from sklearn.tree import export_graphviz
# ----> 3 export_graphviz(clf2, out_file="wine.dot", class_names=wine.target_names,
#       4 feature_names=wine.feature_names[:2], impurity=False, filled=True)
#       5 with open("wine.dot") as f:
#       6     dot_graph = f.read()
#
# NameError: name 'clf2' is not defined

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(max_depth = 1)")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16316\2346370796.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
clf2 = tree.DecisionTreeClassifier(max_depth=3)
clf2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
clf2.score(X_test, y_test)
# Out:
# 0.8444444444444444

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = clf2.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(max_depth = 3)")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16316\547894330.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
clf3 = tree.DecisionTreeClassifier(max_depth=5)
clf3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
clf3.score(X_test, y_test)
# Out:
# 0.8222222222222222

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = clf3.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(max_depth = 5)")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16316\1625158947.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
import graphviz
from sklearn.tree import export_graphviz
export_graphviz(clf2, out_file="wine1.dot", class_names=wine.target_names,
feature_names=wine.feature_names[:2], impurity=False, filled=True)

# %%
with open("wine1.dot") as f:
    dot_graph = f.read()
# graphviz.Source(dot_graph)
print(dot_graph)
# Out:
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="alcohol <= 12.78\nsamples = 133\nvalue = [44, 55, 34]\nclass = class_1", fillcolor="#e7fcef"] ;
# 1 [label="malic_acid <= 2.275\nsamples = 53\nvalue = [0, 46, 7]\nclass = class_1", fillcolor="#57e994"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="alcohol <= 12.49\nsamples = 34\nvalue = [0, 33, 1]\nclass = class_1", fillcolor="#3fe685"] ;
# 1 -> 2 ;
# 3 [label="samples = 28\nvalue = [0, 28, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 2 -> 3 ;
# 4 [label="samples = 6\nvalue = [0, 5, 1]\nclass = class_1", fillcolor="#61ea9a"] ;
# 2 -> 4 ;
# 5 [label="alcohol <= 12.145\nsamples = 19\nvalue = [0, 13, 6]\nclass = class_1", fillcolor="#94f1bb"] ;
# 1 -> 5 ;
# 6 [label="samples = 7\nvalue = [0, 7, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 5 -> 6 ;
# 7 [label="samples = 12\nvalue = [0, 6, 6]\nclass = class_1", fillcolor="#ffffff"] ;
# 5 -> 7 ;
# 8 [label="malic_acid <= 2.235\nsamples = 80\nvalue = [44, 9, 27]\nclass = class_0", fillcolor="#f7d7bf"] ;
# 0 -> 8 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 9 [label="malic_acid <= 1.3\nsamples = 49\nvalue = [38, 7, 4]\nclass = class_0", fillcolor="#eca26d"] ;
# 8 -> 9 ;
# 10 [label="samples = 4\nvalue = [0, 4, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 9 -> 10 ;
# 11 [label="samples = 45\nvalue = [38, 3, 4]\nclass = class_0", fillcolor="#e9975b"] ;
# 9 -> 11 ;
# 12 [label="malic_acid <= 5.725\nsamples = 31\nvalue = [6, 2, 23]\nclass = class_2", fillcolor="#a978ed"] ;
# 8 -> 12 ;
# 13 [label="samples = 30\nvalue = [6, 1, 23]\nclass = class_2", fillcolor="#a673ed"] ;
# 12 -> 13 ;
# 14 [label="samples = 1\nvalue = [0, 1, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 12 -> 14 ;
# }

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:\liuchaochao\DownLoad\anaconda\Lib\site-packages\graphviz'

# %%
graphviz.Source(dot_graph)

# %%
from sklearn.ensemble import RandomForestClassifier
wine = datasets.load_wine()
X = wine.data[:,:2]
y = wine.target
X_train, X_test, y_train, y_test = train_test_split(X,y)
forest = RandomForestClassifier(n_estimators=25,random_state=3)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=25, random_state=3)

# %%
print(forest.score(X_test, y_test))
# Out:
# 0.7777777777777778

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = forest.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:RandomForest")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_16316\762165249.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
