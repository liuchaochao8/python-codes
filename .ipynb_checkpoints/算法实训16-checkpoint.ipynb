# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import tree, datasets
from sklearn.model_selection import train_test_split
wine = datasets.load_wine()
X = wine.data[:,:2]
y = wine.target
X_train, X_test, y_train, y_test = train_test_split(X,y)
clf = tree.DecisionTreeClassifier(max_depth=1)
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=1)

# %%
clf.score(X_test, y_test)
# Out:
# 0.6222222222222222

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
import graphviz
from sklearn.tree import export_graphviz
export_graphviz(clf2, out_file="wine.dot", class_names=wine.target_names,
feature_names=wine.feature_names[:2], impurity=False, filled=True)
with open("wine.dot") as f:
    dot_graph = f.read()
graphviz.Source(dot_graph)

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(max_depth = 1)")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7360\2346370796.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
clf2 = tree.DecisionTreeClassifier(max_depth=3)
clf2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
clf2.score(X_test, y_test)
# Out:
# 0.7777777777777778

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = clf2.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(max_depth = 3)")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7360\547894330.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
clf3 = tree.DecisionTreeClassifier(max_depth=5)
clf3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
clf3.score(X_test, y_test)
# Out:
# 0.8222222222222222

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = clf3.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:(max_depth = 5)")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7360\1625158947.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# %%
import graphviz
from sklearn.tree import export_graphviz
export_graphviz(clf2, out_file="wine1.dot", class_names=wine.target_names,
feature_names=wine.feature_names[:2], impurity=False, filled=True)

# %%
with open("wine1.dot") as f:
    dot_graph = f.read()
# graphviz.Source(dot_graph)
print(dot_graph)
# Out:
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label="alcohol <= 12.745\nsamples = 133\nvalue = [45, 55, 33]\nclass = class_1", fillcolor="#e8fcf1"] ;
# 1 [label="malic_acid <= 2.445\nsamples = 52\nvalue = [0, 47, 5]\nclass = class_1", fillcolor="#4ee88e"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="samples = 37\nvalue = [0, 37, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 1 -> 2 ;
# 3 [label="alcohol <= 12.145\nsamples = 15\nvalue = [0, 10, 5]\nclass = class_1", fillcolor="#9cf2c0"] ;
# 1 -> 3 ;
# 4 [label="samples = 6\nvalue = [0, 6, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 3 -> 4 ;
# 5 [label="samples = 9\nvalue = [0, 4, 5]\nclass = class_2", fillcolor="#e6d7fa"] ;
# 3 -> 5 ;
# 6 [label="malic_acid <= 2.375\nsamples = 81\nvalue = [45, 8, 28]\nclass = class_0", fillcolor="#f7d7bf"] ;
# 0 -> 6 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 7 [label="malic_acid <= 1.3\nsamples = 48\nvalue = [39, 6, 3]\nclass = class_0", fillcolor="#eb9c63"] ;
# 6 -> 7 ;
# 8 [label="samples = 4\nvalue = [0, 4, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 7 -> 8 ;
# 9 [label="samples = 44\nvalue = [39, 2, 3]\nclass = class_0", fillcolor="#e89051"] ;
# 7 -> 9 ;
# 10 [label="malic_acid <= 5.725\nsamples = 33\nvalue = [6, 2, 25]\nclass = class_2", fillcolor="#a674ed"] ;
# 6 -> 10 ;
# 11 [label="samples = 32\nvalue = [6, 1, 25]\nclass = class_2", fillcolor="#a36eec"] ;
# 10 -> 11 ;
# 12 [label="samples = 1\nvalue = [0, 1, 0]\nclass = class_1", fillcolor="#39e581"] ;
# 10 -> 12 ;
# }

# %%
import os
os.environ["PATH"] += os.pathsep + 'D:\liuchaochao\DownLoad\anaconda\Lib\site-packages\graphviz'

# %%
graphviz.Source(dot_graph)

# %%
from sklearn.ensemble import RandomForestClassifier
wine = datasets.load_wine()
X = wine.data[:,:2]
y = wine.target
X_train, X_test, y_train, y_test = train_test_split(X,y)
forest = RandomForestClassifier(n_estimators=25,random_state=3)
forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=25, random_state=3)

# %%
print(forest.score(X_test, y_test))
# Out:
# 0.7777777777777778

# %%
#定义图像中分区的颜色和散点的颜色
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

#分别用样本的两个特征值创建图像和横轴和纵轴
x_min, x_max = X_train[:, 0].min() - 1, X_train[:, 0].max() + 1
y_min, y_max = X_train[:, 1].min() - 1, X_train[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, .02),
                     np.arange(y_min, y_max, .02))
Z = forest.predict(np.c_[xx.ravel(), yy.ravel()])

#给每个分类中的样本分配不同的颜色
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

#用散点把样本表示出来
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("Classifier:RandomForest")

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_7360\762165249.py:15: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolormesh(xx, yy, Z, cmap=cmap_light)
