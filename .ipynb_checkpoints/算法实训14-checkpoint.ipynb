# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
X, y = make_blobs(n_samples=500, centers=5,random_state=8)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=8)
nb = BernoulliNB()
nb.fit(X_train,y_train)
print('模型得分：{:.3f}'.format(nb.score(X_test, y_test)))
# Out:
# 模型得分：0.544

# %%
import matplotlib.pyplot as plt
import numpy as np
x_min, x_max = X[:,0].min()-0.5, X[:,0].max()+0.5
y_min, y_max = X[:,1].min()-0.5, X[:,1].max()+0.5
xx,yy = np.meshgrid(np.arange(x_min, x_max,.02),
                    np.arange(y_min, y_max, .02))
z = nb.predict(np.c_[(xx.ravel(),yy.ravel())]).reshape(xx.shape)
plt.pcolormesh(xx,yy,z,cmap=plt.cm.Pastel1)
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap=plt.cm.cool,edgecolor='k')
plt.scatter(X_test[:,0],X_test[:,1],c=y_test,cmap=plt.cm.cool,marker='*',
            edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title('Classifier: BernoulliNB')
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train, y_train)
print('模型得分：{:.3f}'.format(gnb.score(X_test, y_test)))
# Out:
# 模型得分：0.968

# %%
z = gnb.predict(np.c_[(xx.ravel(),yy.ravel())]).reshape(xx.shape)
plt.pcolormesh(xx,yy,z,cmap=plt.cm.Pastel1)
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap=plt.cm.cool,edgecolor='k')
plt.scatter(X_test[:,0],X_test[:,1],c=y_test,cmap=plt.cm.cool,marker='*',
            edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title('Classifier: GaussianNB')
plt.show()

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

mnb = MultinomialNB()
mnb.fit(X_train_scaled, y_train)
print('模型得分：{:.3f}'.format(mnb.score(X_test_scaled, y_test)))
# Out:
# 模型得分：0.320

# %%
z = mnb.predict(np.c_[(xx.ravel(),yy.ravel())]).reshape(xx.shape)
plt.pcolormesh(xx,yy,z,cmap=plt.cm.Pastel1)
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap=plt.cm.cool,edgecolor='k')
plt.scatter(X_test[:,0],X_test[:,1],c=y_test,cmap=plt.cm.cool,marker='*',
            edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title('Classifier: MultinomialNB')
plt.show()

# %% [markdown]
# 练习
# 1.假设有一个关于某种疾病患者信息的数据集。该数据集包含1000个样本和10个特征。
#
#
# 每个样本都被标记为该疾病的阳性（1）或阴性（0）。
#
# 你需要构建一个模型，基于新患者的特征，选择合适的朴素贝叶斯模型将其分类为该疾病的阳性或阴性。
#
#
# （我们没有真正的数据集，请使用使用make_blobs函数或者其他方式生成一个）

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
X, y = make_blobs(n_samples=1000, n_features=10,centers=2,random_state=427)
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=427)

nb = BernoulliNB()
nb.fit(X_train,y_train)
print('BernoulliNB模型得分：{:.3f}'.format(nb.score(X_test, y_test)))

gnb1 = GaussianNB()
gnb1.fit(X_train, y_train)
print('GaussianNB模型得分：{:.3f}'.format(gnb1.score(X_test, y_test)))

scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
mnb = MultinomialNB()
mnb.fit(X_train_scaled, y_train)
print('MultinomialNB模型得分：{:.3f}'.format(mnb.score(X_test_scaled, y_test)))
# Out:
# BernoulliNB模型得分：1.000
# GaussianNB模型得分：1.000
# MultinomialNB模型得分：1.000

# %%
arr1 = [0.9,0.8,0.3,-0.6,-0.2,0.7,0.4,0.1,0.7,0.3]
arr2 = [-100,-100,-100,100,100,100,100,99,92,19]

# %%
print('BernoulliNB模型预测1:  {:.1f}'.format(nb.predict([arr1])[0]) )
print('BernoulliNB模型预测2:  {:.1f}\n'.format(nb.predict([arr2])[0]) )
print('GaussianNB模型预测1:  {:.1f}'.format(gnb1.predict([arr1])[0]) )
print('GaussianNB模型预测2:  {:.1f}\n'.format(gnb1.predict([arr2])[0]) )
print('MultinomialNB模型预测1:  {:.1f}'.format(mnb.predict([arr1])[0]) )
print('MultinomialNB模型预测2:  {:.1f}'.format(mnb.predict([arr2])[0]) )
# Out:
# BernoulliNB模型预测1:  1.0
# BernoulliNB模型预测2:  1.0
#
# GaussianNB模型预测1:  1.0
# GaussianNB模型预测2:  1.0
#
# MultinomialNB模型预测1:  0.0
# MultinomialNB模型预测2:  1.0

# %%
import matplotlib.pyplot as plt
import numpy as np
x_min, x_max = X[:,0].min()-0.5, X[:,0].max()+0.5
y_min, y_max = X[:,1].min()-0.5, X[:,1].max()+0.5
a_min, a_max = X[:,2].min()-0.5, X[:,2].max()+0.5
b_min, b_max = X[:,3].min()-0.5, X[:,3].max()+0.5
c_min, c_max = X[:,4].min()-0.5, X[:,4].max()+0.5
d_min, d_max = X[:,5].min()-0.5, X[:,5].max()+0.5
e_min, e_max = X[:,6].min()-0.5, X[:,6].max()+0.5
f_min, f_max = X[:,7].min()-0.5, X[:,7].max()+0.5
g_min, g_max = X[:,8].min()-0.5, X[:,8].max()+0.5
h_min, h_max = X[:,9].min()-0.5, X[:,9].max()+0.5
xx,yy = np.meshgrid(np.arange(x_min, x_max,.02),
                    np.arange(y_min, y_max, .02),
                   np.arange(a_min, a_max, .02),
                   np.arange(b_min, b_max, .02),
                   np.arange(c_min, c_max, .02),
                   np.arange(d_min, d_max, .02),
                   np.arange(e_min, e_max, .02),
                   np.arange(f_min, f_max, .02),
                   np.arange(g_min, g_max, .02),
                   np.arange(h_min, h_max, .02))
z = gnb1.predict(np.c_[(xx.ravel(),yy.ravel())]).reshape(xx.shape)
plt.pcolormesh(xx,yy,z,cmap=plt.cm.Pastel1)
plt.scatter(X_train[:,0],X_train[:,1],c=y_train,cmap=plt.cm.cool,edgecolor='k')
plt.scatter(X_test[:,0],X_test[:,1],c=y_test,cmap=plt.cm.cool,marker='*',
            edgecolor='k')
plt.xlim(xx.min(),xx.max())
plt.ylim(yy.min(),yy.max())
plt.title('Classifier: GaussianNB')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [123], line 13
#      11 g_min, g_max = X[:,8].min()-0.5, X[:,8].max()+0.5
#      12 h_min, h_max = X[:,9].min()-0.5, X[:,9].max()+0.5
# ---> 13 xx,yy = np.meshgrid(np.arange(x_min, x_max,.02),
#      14                     np.arange(y_min, y_max, .02),
#      15                    np.arange(a_min, a_max, .02),
#      16                    np.arange(b_min, b_max, .02),
#      17                    np.arange(c_min, c_max, .02),
#      18                    np.arange(d_min, d_max, .02),
#      19                    np.arange(e_min, e_max, .02),
#      20                    np.arange(f_min, f_max, .02),
#      21                    np.arange(g_min, g_max, .02),
#      22                    np.arange(h_min, h_max, .02))
#      23 z = gnb1.predict(np.c_[(xx.ravel(),yy.ravel())]).reshape(xx.shape)
# ...

# %%
#导入学习曲线库
from sklearn.model_selection import learning_curve
#导入随机拆分工具
from sklearn.model_selection import ShuffleSplit
#定义一个函数绘制学习曲线
def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
    n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    #设定横轴标签
    plt.xlabel("Training examples")
    #设定纵轴标签
    plt.ylabel("Score")
    train_sizes, train_scores, test_scores = learning_curve(
    estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    plt.grid()

    plt.plot(train_sizes, train_scores_mean, 'o-', color="r",
    label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="g",
    label="Cross-validation score")
    plt.legend(loc="lower right")
    return plt
#设定图题
#title = "Learning Curves (Naive Bayes)"
#设定拆分数量
cv = ShuffleSplit(n_splits=100, test_size=0.2, random_state=0)

# %%
#设定模型为高斯朴素贝叶斯
estimator = GaussianNB()
#调用我们定义好的函数
plot_learning_curve(nb, "nb", X, y, ylim=(0.9, 1.01), cv=cv, n_jobs=4)
plot_learning_curve(gnb1, "gnb1", X, y, ylim=(0.9, 1.01), cv=cv, n_jobs=4)
plot_learning_curve(mnb, "mnb", X, y, ylim=(0.9, 1.01), cv=cv, n_jobs=4)
#显示图片
plt.show()
